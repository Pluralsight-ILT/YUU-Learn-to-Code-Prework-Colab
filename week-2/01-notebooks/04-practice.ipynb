# %% [markdown]
# # Session 4 Practice: Advanced Logic
#
# Live-coding companion to `04-session.ipynb`. Same code, same order, stripped of the agenda, the written explanations, and the wrap-up.
#
# Use this to demo at the front of the room, or to have students call out the next line while you type. The full write-up lives in the session notebook.

# %% [markdown]
# ## Part 1: Review and Demo

# %% [markdown]
# Let's review key concepts from Session 3 before moving to advanced conditional logic.
#
# **Key Topics from last session:**
# - Writing simple `if-else` statements.
# - Logical operators (`and`, `or`, `not`).
#
# ### Quick Review Questions:
# 1. How do programming languages evaluate expressions with multiple operators?
# 2. What is the difference between `and` and `or` operators?
# 3. In an `if`/`elif`/`else` chain, how many branches run?

# %% [markdown]
# **Demo 1:** Logical operators.

# %%
has_ticket = True
on_time = False

print(has_ticket and on_time)
print(has_ticket or on_time)
print(not on_time)

# %% [markdown]
# **Demo 2:** An `if`/`elif`/`else` chain. Change `hour` and re-run to hit each branch.

# %%
hour = 14

if hour < 12:
    print('Good morning')
elif hour < 18:
    print('Good afternoon')
else:
    print('Good evening')

# %% [markdown]
# ## Part 2: New Information – Structuring Complex Decision Trees

# %% [markdown]
# ### 1. Nested If-Else Statements

# %%
score = 85

if score >= 60:
    print('You passed!')
    if score >= 90:
        print('Excellent work!')
    elif score >= 75:
        print('Good job!')
else:
    print('You failed.')

# %%
age = 25
experience = 2

if age >= 18:
    if experience >= 1:
        print('You are eligible for the job')
    else:
        print('More experience needed')
else:
    print('You are too young for this role')

# %% [markdown]
# ### 2. Deeply Nested Conditions

# %%
age = 30
income = 50000
credit_score = 750

if age >= 18:
    if income >= 25000:
        if credit_score >= 700:
            print('Loan approved')
        else:
            print('Credit score too low')
    else:
        print('Income too low')
else:
    print('Applicant is underage')

# %% [markdown]
# ### 3. Flattening the Logic

# %%
if age >= 18 and income >= 25000 and credit_score >= 700:
    print('Loan approved')
elif age < 18:
    print('Applicant is underage')
elif income < 25000:
    print('Income too low')
else:
    print('Credit score too low')

# %% [markdown]
# ### 4. Multi-Level Decision Structures

# %%
age = 18
membership = True

if age < 12:
    price = 5
elif age < 18:
    price = 8
elif age >= 60:
    price = 6
else:
    price = 10

if membership:
    price = price * 0.9  # 10% discount for members

print('Ticket price:', price)

# %% [markdown]
# ### 5. When Code Breaks

# %% [markdown]
# Run both cells. They differ by one indentation level, and they disagree.

# %%
score = 45

if score >= 60:
    print('Passed')
    if score >= 90:
        print('With honors')
else:
    print('Did not pass')

# %%
score = 45

if score >= 60:
    print('Passed')
    if score >= 90:
        print('With honors')
    else:
        print('Did not pass')

# %% [markdown]
# ## Part 3: We Do and Wrap Up
#
# Time to build a decision tree from scratch.

# %% [markdown]
# ### Exercise 1: Shipping Cost (warm-up)
# Shipping is free on orders of $50 or more. Under $50, it's $6, unless the customer is a member, in which case it's $3. Print the shipping cost.

# %%
# Exercise 1: shipping cost
order_total = 34
member = True

# Your logic goes here

# %% [markdown]
# ### Exercise 2: Smart Home Automation System
#
# A smart home system controls the air conditioning and heating based on temperature and occupancy.
#
# **Requirements:**
# - If the room temperature is below 60°F, the heater turns on.
# - If the room temperature is above 75°F, the air conditioner turns on.
# - If no one is in the room, the system turns off all devices.
# - If someone is sleeping, the system keeps the temperature between **65°F and 72°F**.
#
# Using the predefined values below, nested conditions, and `elif` structures, determine the correct action and print it.
#
# Which requirement should be tested *first*, no matter what the others say?
#
# Modify the values to test different scenarios.

# %%
# Exercise 2: smart home automation
temperature = 75
occupied = True
sleeping = False

# Your logic goes here

# %% [markdown]
# ### Bonus
# Pick one branch of the Exercise 2 solution that ended up two or three levels deep and rewrite it flat, using `and`.

# %%
# Bonus: flatten one branch
# Your logic goes here

# %% [markdown]
# ### Additional Exercise
# Add a fourth requirement: if a window is open, the system turns off all devices and prints a warning, regardless of everything else. Where does this check belong?

# %%
# Additional: add the window check
temperature = 80
occupied = True
sleeping = False
window_open = True

# Your logic goes here
